# %% [markdown]
# # Oefening: Cross-validatie

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Lees de gegevens
train_data = pd.read_csv('../data/train.csv', index_col='Id')
test_data = pd.read_csv('../data/test.csv', index_col='Id')

# Verwijder rijen met ontbrekend doel, scheid doel van voorspellers
train_data.dropna(axis=0, subset=['SalePrice'], inplace=True)
y = train_data.SalePrice
train_data.drop(['SalePrice'], axis=1, inplace=True)

# Selecteer alleen numerieke kolommen
numerieke_kolommen = [cname for cname in train_data.columns if train_data[cname].dtype in ['int64', 'float64']]
X = train_data[numerieke_kolommen].copy()
X_test = test_data[numerieke_kolommen].copy()

# %%
X.head()
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# Id                                                    ...
# 1           2003       196.0         706           0  ...         548
# 2           1976         0.0         978           0  ...         460
# 3           2002       162.0         486           0  ...         608
# 4           1970         0.0         216           0  ...         642
# 5           2000       350.0         655           0  ...         836
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

mijn_pijpleiding = Pipeline(steps=[
   ('preprocessor', SimpleImputer()),
   ('model', RandomForestRegressor(n_estimators=50, random_state=0))
   ])

# %%
from sklearn.model_selection import cross_val_score

# Vermenigvuldig met -1 omdat sklearn *negatieve* MAE berekent
scores = -1 * cross_val_score(mijn_pijpleiding, X, y, cv=5, scoring='neg_mean_absolute_error')

print("Gemiddelde MAE-score:", scores.mean())

# %% [markdown]
# ## Stap 1: Schrijf een nuttige functie

# %%
def get_score(n_estimators):
###Geef de gemiddelde MAE over 3 CV-vouwen van het willekeurige bosmodel terug.

### Trefwoordargument:
### n_estimators -- het aantal bomen in het bos

#####
# Vervang deze body met uw eigen code

# %% [markdown]
# ## Stap 2: Test verschillende parameterwaarden

# %%
resultaten = ____ # Uw code hier

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(list(results.keys()), list(results.values()))
plt.show()

# %% [markdown]
# ## Stap 3: Vind de beste parameterwaarde

# %%
n_estimators = #####
